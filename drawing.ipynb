# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for Result 1
result1 = {
    # 'CIP': {

"NIT":{
"Logistic Regression": {'AUROC': 0.7, 'AUPRC': 0.453, 'Sensitivity': 0.627, 'Specificity': 0.667, 'PPV': 0.351, 'F1 Score': 0.45},
"XGBoost": {'AUROC': 0.708, 'AUPRC': 0.463, 'Sensitivity': 0.636, 'Specificity': 0.663, 'PPV': 0.351, 'F1 Score': 0.453}
},

"SXT":{
"Logistic Regression": {'AUROC': 0.651, 'AUPRC': 0.431, 'Sensitivity': 0.697, 'Specificity': 0.498, 'PPV': 0.319, 'F1 Score': 0.438},
"XGBoost": {'AUROC': 0.651, 'AUPRC': 0.43, 'Sensitivity': 0.722, 'Specificity': 0.466, 'PPV': 0.313, 'F1 Score': 0.437}
},
"CIP":{
"Logistic Regression": {'AUROC': 0.774, 'AUPRC': 0.531, 'Sensitivity': 0.651, 'Specificity': 0.749, 'PPV': 0.431, 'F1 Score': 0.519},
"XGBoost": {'AUROC': 0.784, 'AUPRC': 0.551, 'Sensitivity': 0.652, 'Specificity': 0.762, 'PPV': 0.445, 'F1 Score': 0.529}
},

"LVX":{
"Logistic Regression": {'AUROC': 0.789, 'AUPRC': 0.56, 'Sensitivity': 0.586, 'Specificity': 0.831, 'PPV': 0.497, 'F1 Score': 0.538},
"XGBoost": {'AUROC': 0.792, 'AUPRC': 0.567, 'Sensitivity': 0.552, 'Specificity': 0.857, 'PPV': 0.522, 'F1 Score': 0.537}
}


}



# our us
result2 = {


"NIT": 
{"Logistic Regression": {'AUROC': 0.671, 'AUPRC': 0.375, 'Sensitivity': 0.615, 'Specificity': 0.638, 'PPV': 0.316, 'F1 Score': 0.418},
"XGBoost": {'AUROC': 0.674, 'AUPRC': 0.385, 'Sensitivity': 0.712, 'Specificity': 0.537, 'PPV': 0.295, 'F1 Score': 0.417}
},

"SXT": 
{"Logistic Regression": {'AUROC': 0.651, 'AUPRC': 0.431, 'Sensitivity': 0.663, 'Specificity': 0.542, 'PPV': 0.328, 'F1 Score': 0.439},
"XGBoost": {'AUROC': 0.651, 'AUPRC': 0.43, 'Sensitivity': 0.722, 'Specificity': 0.466, 'PPV': 0.313, 'F1 Score': 0.437}
},

"CIP": 
{"Logistic Regression": {'AUROC': 0.79, 'AUPRC': 0.557, 'Sensitivity': 0.605, 'Specificity': 0.819, 'PPV': 0.472, 'F1 Score': 0.53},
"XGBoost": {'AUROC': 0.793, 'AUPRC': 0.563, 'Sensitivity': 0.553, 'Specificity': 0.861, 'PPV': 0.516, 'F1 Score': 0.534}
},

"LVX": 
{"Logistic Regression": {'AUROC': 0.799, 'AUPRC': 0.566, 'Sensitivity': 0.619, 'Specificity': 0.818, 'PPV': 0.488, 'F1 Score': 0.546},
"XGBoost": {'AUROC': 0.8, 'AUPRC': 0.57, 'Sensitivity': 0.56, 'Specificity': 0.86, 'PPV': 0.528, 'F1 Score': 0.544}
}


}

# dubai
result3 = {


"NIT": 
{"Logistic Regression": {'AUROC': 0.825, 'AUPRC': 0.659, 'Sensitivity': 0.666, 'Specificity': 0.865, 'PPV': 0.647, 'F1 Score': 0.656},
"XGBoost": {'AUROC': 0.839, 'AUPRC': 0.695, 'Sensitivity': 0.695, 'Specificity': 0.873, 'PPV': 0.67, 'F1 Score': 0.683}
},

"CIP": 
{"Logistic Regression": {'AUROC': 0.714, 'AUPRC': 0.51, 'Sensitivity': 0.775, 'Specificity': 0.504, 'PPV': 0.386, 'F1 Score': 0.516},
"XGBoost": {'AUROC': 0.745, 'AUPRC': 0.562, 'Sensitivity': 0.696, 'Specificity': 0.658, 'PPV': 0.451, 'F1 Score': 0.547}
},
"SXT": {
"Logistic Regression": {'AUROC': 0, 'AUPRC': 0, 'Sensitivity': 0, 'Specificity': 0, 'PPV': 0, 'F1 Score': 0},
"XGBoost": {'AUROC': 0, 'AUPRC': 0, 'Sensitivity': 0, 'Specificity': 0, 'PPV': 0, 'F1 Score': 0}
},

"LVX": 
{"Logistic Regression": {'AUROC': 0.729, 'AUPRC': 0.491, 'Sensitivity': 0.687, 'Specificity': 0.645, 'PPV': 0.366, 'F1 Score': 0.478},
"XGBoost": {'AUROC': 0.727, 'AUPRC': 0.518, 'Sensitivity': 0.478, 'Specificity': 0.828, 'PPV': 0.454, 'F1 Score': 0.465}
}

}
# Data for Result 2
result4 = {
    'CIP': {
        'Logistic Regression': {'AUROC': 0.789, 'AUPRC': 0.590, 'Sensitivity': 0.601, 'Specificity': 0.832, 'PPV': 0.539, 'F1 Score': 0.569},
        'XGBoost': {'AUROC': 0.811, 'AUPRC': 0.617, 'Sensitivity': 0.727, 'Specificity': 0.749, 'PPV': 0.487, 'F1 Score': 0.583}
    },
    'LVX': {
        'Logistic Regression': {'AUROC': 0.791, 'AUPRC': 0.592, 'Sensitivity': 0.632, 'Specificity': 0.809, 'PPV': 0.524, 'F1 Score': 0.573},
        'XGBoost': {'AUROC': 0.814, 'AUPRC': 0.624, 'Sensitivity': 0.710, 'Specificity': 0.769, 'PPV': 0.506, 'F1 Score': 0.591}
    },
    'NIT': {
        'Logistic Regression': {'AUROC': 0.662, 'AUPRC': 0.381, 'Sensitivity': 0.623, 'Specificity': 0.619, 'PPV': 0.333, 'F1 Score': 0.434},
        'XGBoost': {'AUROC': 0.686, 'AUPRC': 0.411, 'Sensitivity': 0.673, 'Specificity': 0.59, 'PPV': 0.334, 'F1 Score': 0.446}
    },
    'SXT': {
        'Logistic Regression': {'AUROC': 0.666, 'AUPRC': 0.467, 'Sensitivity': 0.568, 'Specificity': 0.674, 'PPV': 0.391, 'F1 Score': 0.463},
        'XGBoost': {'AUROC': 0.701, 'AUPRC': 0.524, 'Sensitivity': 0.660, 'Specificity': 0.618, 'PPV': 0.339, 'F1 Score': 0.440}
    }
}

# Combine all results into a list for easier iteration
results = [result1, result2, result3, result4]
result_labels = ['US+Dubai(Ours)', 'US(Ours)', 'Dubai(Ours)', 'US(Other paper)']

# Plotting
metrics = ['AUROC', 'AUPRC', 'Sensitivity', 'Specificity', 'PPV', 'F1 Score']
drugs = ['CIP', 'LVX', 'NIT', 'SXT']

fig, axs = plt.subplots(len(drugs)//2 + len(drugs)%2, 2, figsize=(14, 10))

# colors = ['b', 'g', 'r', 'c']  # Define colors for each result
colors = ['#dbdb8d', '#9edae5', '#17becf', '#aec7e8']  # 黄青蓝灰

for i, drug in enumerate(drugs):
    ax = axs[i//2, i%2]
    
    # Iterate through each result and plot
    for j, result in enumerate(results):
        result_data = result[drug]['Logistic Regression'].values()
        
        # Bar chart comparison
        ax.bar(np.arange(len(metrics)) + j * 0.15 - (len(results) - 1) * 0.075, result_data,
               width=0.15, label=result_labels[j], color=colors[j])
    
    ax.set_xticks(np.arange(len(metrics)))
    ax.set_xticklabels(metrics)
    ax.set_title(f'Performance for {drug} in Logistic Regression')
    ax.set_ylabel('Score')
    ax.legend()

plt.tight_layout()
plt.show()

# Repeat the process for XGBoost comparison
fig, axs = plt.subplots(len(drugs)//2 + len(drugs)%2, 2, figsize=(14, 10))

for i, drug in enumerate(drugs):
    ax = axs[i//2, i%2]
    
    # Iterate through each result and plot
    for j, result in enumerate(results):
        result_data = result[drug]['XGBoost'].values()
        
        # Bar chart comparison
        ax.bar(np.arange(len(metrics)) + j * 0.15 - (len(results) - 1) * 0.075,
               result_data, width=0.15, label=result_labels[j], color=colors[j])
    
    ax.set_xticks(np.arange(len(metrics)))
    ax.set_xticklabels(metrics)
    ax.set_title(f'Performance for {drug} in XGBoost')
    ax.set_ylabel('Score')
    
    ax.legend()

plt.tight_layout()
plt.show()
